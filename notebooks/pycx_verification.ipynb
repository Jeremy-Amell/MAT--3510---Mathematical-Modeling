# %% [markdown]
# # PyCX Verification
# This notebook checks that the active Python kernel can import the PyCX simulator and its usual dependencies.

# %%
from pathlib import Path
import numpy
import scipy
import matplotlib
import networkx
import pycxsimulator

print('cwd=', Path.cwd())
print('pycxsimulator=', pycxsimulator.__file__)
print('numpy=', numpy.__version__)
print('scipy=', scipy.__version__)
print('matplotlib=', matplotlib.__version__)
print('networkx=', networkx.__version__)
print('simulator_class=', hasattr(pycxsimulator, 'GUI') or hasattr(pycxsimulator, 'PyCXSimulator'))
print('example_script=', (Path.cwd().parent / 'src' / 'pycx_random_walk.py').resolve())
# Out:
# cwd= f:\MAT--3510---Mathematical-Modeling\notebooks
# pycxsimulator= c:\Users\jerem\anaconda3\Lib\site-packages\pycxsimulator.py
# numpy= 1.26.4
# scipy= 1.13.1
# matplotlib= 3.10.0
# networkx= 3.4.2
# simulator_class= True
# example_script= F:\MAT--3510---Mathematical-Modeling\src\pycx_random_walk.py
